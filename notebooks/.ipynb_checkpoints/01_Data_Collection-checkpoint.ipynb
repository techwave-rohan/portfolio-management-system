# %%
import sys
# !{sys.executable} -m pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import yfinance as yf
aapl=yf.Ticker("AAPL")
print(aapl.info["longName"])
# Out:
# Apple Inc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stocks=["AAPL","MSFT","GOOGL","AMZN","NVDA"]
data=yf.download(stocks,start="2020-01-01",end="2025-01-01",auto_adjust=True)
data.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
# Price           Close                                                   High  \
# Ticker           AAPL       AMZN      GOOGL        MSFT      NVDA       AAPL
# Date
# 2020-01-02  72.333855  94.900497  67.832520  151.829544  5.963803  72.394063
# 2020-01-03  71.630653  93.748497  67.477654  149.939041  5.868348  72.389273
# 2020-01-06  72.201424  95.143997  69.276207  150.326538  5.892957  72.239958
# 2020-01-07  71.861839  95.343002  69.142395  148.955933  5.964302  72.466322
# 2020-01-08  73.017830  94.598503  69.634529  151.328537  5.975487  73.318870
#
# Price                                                   ...       Open  \
# Ticker           AMZN      GOOGL        MSFT      NVDA  ...       AAPL
# Date                                                    ...
# 2020-01-02  94.900497  67.832520  151.933525  5.963803  ...  71.344032
# 2020-01-03  94.309998  68.083782  151.196255  5.912099  ...  71.563221
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2020-01-02 to 2024-12-31
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Close, AAPL)    1258 non-null   float64
#  1   (Close, AMZN)    1258 non-null   float64
#  2   (Close, GOOGL)   1258 non-null   float64
#  3   (Close, MSFT)    1258 non-null   float64
#  4   (Close, NVDA)    1258 non-null   float64
#  5   (High, AAPL)     1258 non-null   float64
#  6   (High, AMZN)     1258 non-null   float64
#  7   (High, GOOGL)    1258 non-null   float64
#  8   (High, MSFT)     1258 non-null   float64
#  9   (High, NVDA)     1258 non-null   float64
#  10  (Low, AAPL)      1258 non-null   float64
#  11  (Low, AMZN)      1258 non-null   float64
#  12  (Low, GOOGL)     1258 non-null   float64
#  13  (Low, MSFT)      1258 non-null   float64
#  14  (Low, NVDA)      1258 non-null   float64
#  15  (Open, AAPL)     1258 non-null   float64
# ...

# %%
close=data["Close"]
close.head()
# Out:
# Ticker           AAPL       AMZN      GOOGL        MSFT      NVDA
# Date
# 2020-01-02  72.333855  94.900497  67.832520  151.829544  5.963803
# 2020-01-03  71.630653  93.748497  67.477654  149.939041  5.868348
# 2020-01-06  72.201424  95.143997  69.276207  150.326538  5.892957
# 2020-01-07  71.861839  95.343002  69.142395  148.955933  5.964302
# 2020-01-08  73.017830  94.598503  69.634529  151.328537  5.975487

# %%
close.isnull().sum()
# Out:
# Ticker
# AAPL     0
# AMZN     0
# GOOGL    0
# MSFT     0
# NVDA     0
# dtype: int64

# %%
close.to_csv("C:/ML_Projects/portfolio-management-system/data/stock_prices.csv")

# %%
df=pd.read_csv("C:/ML_Projects/portfolio-management-system/data/stock_prices.csv",index_col=0,parse_dates=True)

# %% [raw]
# df.head()

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2020-01-02 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    1258 non-null   float64
#  1   AMZN    1258 non-null   float64
#  2   GOOGL   1258 non-null   float64
#  3   MSFT    1258 non-null   float64
#  4   NVDA    1258 non-null   float64
# dtypes: float64(5)
# memory usage: 59.0 KB
#               AAPL         AMZN        GOOGL         MSFT         NVDA
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    151.377786   146.713811   118.068270   285.724092    38.388613
# std      41.851998    32.004698    32.234702    81.058643    38.176862
# min      54.163708    81.820000    52.243248   128.358337     4.885131
# 25%     126.279112   121.000000    93.121775   226.536346    13.552992
# 50%     149.968605   153.872498   118.647919   273.605835    21.206260
# ...

# %%
plt.figure(figsize=(12,6))
for stocks in df.columns:
    plt.plot(df.index,df[stocks],label=stocks)

plt.title("Stock Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()
